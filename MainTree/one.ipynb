# %%
from recorder import grabar_audio
from analyzer import analizar_espectro
from classifier import predecir_instrumento

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
archivo = grabar_audio(duracion=5)
analizar_espectro(archivo)
instrumento = predecir_instrumento(archivo)
print(f"Instrumento detectado: {instrumento}")
# Out:
# Grabando 5 segundos...
# Grabación guardada como grabacion.wav
# 🔊 Posibles instrumentos detectados:
# - Speech (0.864)
# - "Inside (0.019)
# - "Outside (0.008)
# - Air brake (0.007)
# - Vehicle (0.007)
# Instrumento detectado: Speech
