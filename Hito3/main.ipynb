# %%
# Ejecutar GUI desde Jupyter Notebook
from gui_interface import main as iniciar_gui

# Llamar a la función principal (esto abrirá una ventana externa)
iniciar_gui()

# 🔚 Finaliza kernel después de lanzar GUI
import os
os._exit(0)
# Out:
# Grabando 7 segundos...
# Grabación guardada como grabacion.wav
#
# ...
# 🎵 TOP 5 INSTRUMENTOS DETECTADOS
# ...
# 1. Guitar               | 0.0691 | ██████
# 2. Piano                | 0.0428 | ████
# 3. Electric guitar      | 0.0317 | ███
# 4. Electric piano       | 0.0159 | █
# 5. Acoustic guitar      | 0.0087 |
# ...
#
# ✅ RESULTADO FINAL:
#    🎯 Instrumento: GUITAR
#    📊 Confianza: 0.0691 (6.9%)
# Grabando 7 segundos...
# Grabación guardada como grabacion.wav
# Grabando 7 segundos...
# Grabación guardada como grabacion.wav
#
# ...
# 🎵 TOP 5 INSTRUMENTOS DETECTADOS
# ...
# 1. Piano                | 0.0383 | ███
# 2. Guitar               | 0.0161 | █
# 3. Electric piano       | 0.0103 | █
# 4. Organ                | 0.0067 |
# 5. Electric guitar      | 0.0030 |
# ...
#
# ✅ RESULTADO FINAL:
#    🎯 Instrumento: PIANO
#    📊 Confianza: 0.0383 (3.8%)

# %%
import os
os._exit(00)
