# %%
from recorder import grabar_audio
from analyzer import analizar_espectro
from classifier import predecir_instrumento

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def main():
    archivo = grabar_audio(duracion=7)
    analizar_espectro(archivo)
    resultado=predecir_instrumento(archivo, umbral_confianza=0.25)
    if resultado is None:
        print("👉 No se detectó ningún instrumento:")
    else:
        nombre, confianza = resultado
        print(f"✅ Resultado final: {nombre.upper()} ({confianza:.2f})")
    
 #  print(f"\n🎵 Instrumento detectado: {instrumento}")

if __name__ == "__main__":
    main()
# Out:
# Grabando 7 segundos...
# Grabación guardada como grabacion.wav
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 14
#      11  #  print(f"\n🎵 Instrumento detectado: {instrumento}")
#      13 if __name__ == "__main__":
# ---> 14     main()
#
# Cell In[33], line 4, in main()
#       2 archivo = grabar_audio(duracion=7)
#       3 analizar_espectro(archivo)
# ----> 4 resultado=predecir_instrumento(archivo, umbral_confianza=0.25)
#       5 if resultado is None:
#       6     print("👉 No se detectó ningún instrumento:")
#
# TypeError: predecir_instrumento() got an unexpected keyword argument 'umbral_confianza'
